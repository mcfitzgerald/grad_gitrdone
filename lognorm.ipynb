# %%
import numpy as np
import scipy as sp
import matplotlib as mp
import pickle
from scipy import optimize
from scipy import stats
import matplotlib.pyplot as plt
import sys, copy, emcee, corner
from itertools import product
# %matplotlib inline

# %%
def loguniform(low=0, high=1, size=None):
    return np.exp(np.random.uniform(low, high, size))

# %%
def randomparms2(pop):
    return ((np.random.lognormal(size=4)*np.random.choice(pop,4)) * (loguniform(size=4)/10))

# %%
randparmsetLN = np.array([randomparms2(np.array([0.001,0.01,.1,1.,10.,100.,1000.,10000.])) for i in range(60000)])

# %%
plt.loglog(randparmsetLN[:,0],randparmsetLN[:,3],'.')
